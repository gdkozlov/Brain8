# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from spiker_stream import Streamer

# %matplotlib notebook

# %%
streamer = Streamer(port='/dev/cu.usbserial-DJ00E2W2', max_time=10000)

# %%
streamer.stream()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
streamer.save_data()

# %%
streamer.save_events()

# %%
streamer.close()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os

for file in os.listdir('gleb_rights'):
    with open('gleb_rights/'+file, 'r') as f:
        x = [float(pt) for pt in f.readlines()]

    plt.plot(x)
    plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
with open('20230521-190358.txt', 'r') as f:
    x = [float(pt) for pt in f.readlines()]
        
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
with open('20230521-161311.txt', 'r') as f:
    x = [float(pt) for pt in f.readlines()]
        
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
with open('20230521-161312.txt', 'r') as f:
    x = [float(pt) for pt in f.readlines()]
        
plt.plot(x)
plt.show()
