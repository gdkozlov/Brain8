# %%
import serial
from spiker_stream import Streamer

# %matplotlib notebook

# %%
streamer = Streamer(port='COM4', max_time=5)

# %%
streamer.stream()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# streamer.save_data("test.wav")

# %%
streamer.close()
