# %%
import serial
from spiker_stream import Streamer

# %matplotlib notebook
# Out:
# 1.2.0

# %%
streamer = Streamer(port='COM3', max_time=5)

# %%
streamer.stream()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# streamer.save_data("test.wav")

# %%
streamer.close()
