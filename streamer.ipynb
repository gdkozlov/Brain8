# %%
import serial
from spiker_stream import Streamer

# %matplotlib notebook

# %%
streamer = Streamer(port='COM3', max_time=20)

# %%
streamer.stream()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# streamer.save_data("test.wav")

# %%
streamer.ser.close()
